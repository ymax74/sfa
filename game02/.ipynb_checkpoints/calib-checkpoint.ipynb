# %%
from math import *
import numpy as np

import pandas as pd
import requests
import io

from astropy.io import fits
from astropy.wcs import WCS
from astropy.time import Time
from astropy.time import TimeDelta

from scipy.optimize import curve_fit

from astropy import units as u
from astropy.coordinates import SkyCoord

import glob
import os
import re

import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm
# %matplotlib widget

# %%
upath = 'fits/'
filelist = sorted(glob.glob(f'{upath}Uranus*wcs.fits'))
print('{}'.format(filelist))
# Out:
# ['fits/Uranus_R_4_0001_wcs.fits', 'fits/Uranus_R_4_0002_wcs.fits', 'fits/Uranus_R_4_0003_wcs.fits', 'fits/Uranus_R_4_0004_wcs.fits', 'fits/Uranus_R_4_0005_wcs.fits']

# %%
hdul = fits.open(filelist[4])
img = (hdul[0].data).astype(float)
h, w = np.shape(img)
hdr = hdul[0].header
hdr
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                   32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                 2072
# NAXIS2  =                 1410
# EXTEND  =                    T
# TARGET  = 'Uranus  '
# DATE-OBS= '2025-09-21T22:42:59.873596'
# DATE-END= '2025-09-21T22:43:10.365809'
# RA      = '03:55:37.2'
# DEC     = '+20:08:58.4'
# EXPTIME =                 10.0
# FOCUS   =                 6250
# FILTER  = 'R       '
# BIN     =                    4
# GAIN    =                  100
# TEMP    =                -10.0
# GTEMP   =                 12.5
# OBSERVER= 'ASSY    '
# MPC     = '217     '
# COMMENT Original key: "END"
# COMMENT
# COMMENT --Start of Astrometry.net WCS solution--
# COMMENT --Put in by the new-wcs program--
# COMMENT
# WCSAXES =                    2 / no comment
# CTYPE1  = 'RA---TAN-SIP' / TAN (gnomic) projection + SIP distortions
# CTYPE2  = 'DEC--TAN-SIP' / TAN (gnomic) projection + SIP distortions
# EQUINOX =               2000.0 / Equatorial coordinates definition (yr)
# LONPOLE =                180.0 / no comment
# LATPOLE =                  0.0 / no comment
# CRVAL1  =        58.9159857586 / RA  of reference point
# CRVAL2  =        20.1538380712 / DEC of reference point
# CRPIX1  =               1036.5 / X reference pixel
# CRPIX2  =                705.5 / Y reference pixel
# CUNIT1  = 'deg     ' / X pixel scale units
# CUNIT2  = 'deg     ' / Y pixel scale units
# CD1_1   =   -0.000135885863912 / Transformation matrix
# CD1_2   =   -2.52965337348E-06 / no comment
# CD2_1   =    2.60277919927E-06 / no comment
# CD2_2   =   -0.000136008881673 / no comment
# IMAGEW  =                 2072 / Image width,  in pixels.
# IMAGEH  =                 1410 / Image height, in pixels.
# A_ORDER =                    2 / Polynomial order, axis 1
# A_0_0   =                    0 / no comment
# A_0_1   =                    0 / no comment
# A_0_2   =   -3.01058124399E-07 / no comment
# A_1_0   =                    0 / no comment
# A_1_1   =   -1.06756064275E-06 / no comment
# A_2_0   =   -2.54080260138E-07 / no comment
# B_ORDER =                    2 / Polynomial order, axis 2
# B_0_0   =                    0 / no comment
# B_0_1   =                    0 / no comment
# B_0_2   =   -5.46419473523E-07 / no comment
# B_1_0   =                    0 / no comment
# B_1_1   =    1.30714113839E-07 / no comment
# B_2_0   =   -3.72821711324E-07 / no comment
# AP_ORDER=                    2 / Inv polynomial order, axis 1
# AP_0_0  =    9.56460685982E-07 / no comment
# AP_0_1  =    5.50712590626E-07 / no comment
# AP_0_2  =    3.01055935098E-07 / no comment
# AP_1_0  =    6.80627541774E-07 / no comment
# AP_1_1  =    1.06755748384E-06 / no comment
# AP_2_0  =    2.54078633444E-07 / no comment
# BP_ORDER=                    2 / Inv polynomial order, axis 2
# BP_0_0  =    7.37746127073E-07 / no comment
# BP_0_1  =    6.31627824401E-07 / no comment
# BP_0_2  =    5.46417895198E-07 / no comment
# BP_1_0  =    7.38186096764E-08 / no comment
# BP_1_1  =   -1.30715324017E-07 / no comment
# BP_2_0  =    3.72820487623E-07 / no comment
# HISTORY Created by the Astrometry.net suite.
# HISTORY For more details, see http://astrometry.net.
# HISTORY Git URL https://github.com/dstndstn/astrometry.net
# HISTORY Git revision 0.97
# HISTORY Git date Mon_Dec_2_14:50:59_2024_-0500
# HISTORY This is a WCS header was created by Astrometry.net.
# DATE    = '2026-02-21T02:35:05' / Date this file was created.
# COMMENT -- onefield solver parameters: --
# COMMENT Index(0):
# COMMENT   /Users/ymax/Documents/astrometry-net/index-5200/LITE/index
# COMMENT   -52m1-00.fits
# COMMENT Index(1):
# COMMENT   /Users/ymax/Documents/astrometry-net/index-5200/LITE/index
# COMMENT   -5206-00.fits
# COMMENT Index(2):
# COMMENT   /Users/ymax/Documents/astrometry-net/index-5200/LITE/index
# COMMENT   -5205-00.fits
# COMMENT Index(3):
# COMMENT   /Users/ymax/Documents/astrometry-net/index-5200/LITE/index
# COMMENT   -5204-00.fits
# COMMENT Index(4):
# COMMENT   /Users/ymax/Documents/astrometry-net/index-5200/LITE/index
# COMMENT   -5203-00.fits
# COMMENT Index(5):
# COMMENT   /Users/ymax/Documents/astrometry-net/index-5200/LITE/index
# COMMENT   -5202-00.fits
# COMMENT Index(6):
# COMMENT   /Users/ymax/Documents/astrometry-net/index-5200/LITE/index
# COMMENT   -5201-00.fits
# COMMENT Index(7):
# COMMENT   /Users/ymax/Documents/astrometry-net/index-5200/LITE/index
# COMMENT   -5200-00.fits
# COMMENT Field name:
# COMMENT   /Users/ymax/Documents/fits/URANUS/20250921/Uranus_R_4_0005
# COMMENT   .axy
# COMMENT Field scale lower: 0.1 arcsec/pixel
# COMMENT Field scale upper: 0.5 arcsec/pixel
# COMMENT X col name: X_IMAGE
# COMMENT Y col name: Y_IMAGE
# COMMENT Start obj: 10
# COMMENT End obj: 20
# COMMENT Solved_in: (null)
# COMMENT Solved_out:
# COMMENT   /Users/ymax/Documents/fits/URANUS/20250921/Uranus_R_4_0005
# COMMENT   .solved
# COMMENT Parity: 2
# COMMENT Codetol: 0.01
# COMMENT Verify pixels: 1 pix
# COMMENT Maxquads: 0
# COMMENT Maxmatches: 0
# COMMENT Cpu limit: 300.000000 s
# COMMENT Time limit: 0 s
# COMMENT Total time limit: 0 s
# COMMENT Total CPU limit: 300.000000 s
# COMMENT Tweak: yes
# COMMENT Tweak AB order: 2
# COMMENT Tweak ABP order: 2
# COMMENT --
# COMMENT -- properties of the matching quad: --
# COMMENT index id: 5204
# COMMENT index healpix: 0
# COMMENT index hpnside: 2
# COMMENT log odds: 242.427
# COMMENT odds: 1.92682e+105
# COMMENT quadno: 208730
# COMMENT stars: 387246,387237,387249,387242
# COMMENT field: 4,5,11,7
# COMMENT code error: 0.00114581
# COMMENT nmatch: 29
# COMMENT nconflict: 0
# COMMENT nfield: 57
# COMMENT nindex: 31
# COMMENT scale: 0.489498 arcsec/pix
# COMMENT parity: 1
# COMMENT quads tried: 155
# COMMENT quads matched: 21
# COMMENT quads verified: 0
# COMMENT objs tried: 12
# COMMENT cpu time: 0.000383
# COMMENT --
# COMMENT
# COMMENT --End of Astrometry.net WCS--
# COMMENT --(Put in by the new-wcs program)--
# COMMENT

# %%
def angular_distance(ra,dec,RA,DEC):
    return acos(sin(dec)*sin(DEC)+cos(dec)*cos(DEC)*cos(ra-RA))

def equatorial_to_tangential(ra,dec,RA,DEC):
    ksi = cos(dec)*sin(ra-RA)/(sin(dec)*sin(DEC)+cos(dec)*cos(DEC)*cos(ra-RA))
    eta = (sin(dec)*cos(DEC)-cos(dec)*sin(DEC)*cos(ra-RA))/(sin(dec)*sin(DEC)+cos(dec)*cos(DEC)*cos(ra-RA))
    return ksi,eta

def tangential_to_equatorial(ksi,eta,RA,Dec):
    x,y,z = np.dot(np.array([[-sin(RA),-cos(RA) * sin(Dec),cos(RA) * cos(Dec)],
                             [cos(RA),-sin(RA) * sin(Dec),sin(RA) * cos(Dec)],
                             [0,cos(Dec),sin(Dec)]]),
                   np.array([ksi,eta,1]))/sqrt(1+ksi*ksi+eta*eta)
    ra = atan2(y,x)
    dec = atan2(z,sqrt(x*x+y*y))
    if(ra<0):
        ra+=2*pi
    return ra,dec

# %%
### Получаем ra, dec, gmag для звёзд в окрестности кадра

# %%
ra0, dec0 = float(hdr["CRVAL1"]), float(hdr["CRVAL2"])
ra0, dec0
# Out:
# (58.9159857586, 20.1538380712)

# %%
t = Time(hdr['DATE-OBS'], format='isot')
t+=TimeDelta(float(hdr['EXPTIME']), format='sec')/2
JD = float(t.copy(format='jd').value)
yr = float(t.copy(format='jyear').value) 


fov = 0.6

JD, fov
# Out:
# (2460940.446584185, 0.6)

# %%
def get_Gaia_data(yr, lm1,lm2, gdf):
    ra,dec,gmag = [],[],[]
    for index, row in gdf.iterrows():
        G = row['phot_g_mean_mag']
        if (not isnan(G)) and (lm1<G<lm2):
            ra0,dec0,pmra,pmdec,ep = \
                radians(row['ra']), \
                radians(row['dec']),\
                radians(row['pmra']/3600000.0),\
                radians(row['pmdec']/3600000.0),\
                row['ref_epoch']
            if not isnan(pmra):
                alpha,delta = np.degrees(tangential_to_equatorial(pmra*(yr-ep),pmdec*(yr-ep),ra0,dec0))
                ra.append(alpha)
                dec.append(delta)
                gmag.append(G)
    return np.array(ra),np.array(dec),np.array(gmag)

# %%
response = requests.get(f'http://sfa.puldb.ru:9810?cmd=box&ra={ra0}&dec={dec0}&fov={fov}')
df = pd.read_csv(io.StringIO(response.content.decode('utf-8')))
df
# Out:
#               solution_id                 designation          source_id  \
# 0     1636148068921376768  Gaia DR3 50924946193250304  50924946193250304
# 1     1636148068921376768  Gaia DR3 50924950488748032  50924950488748032
# 2     1636148068921376768  Gaia DR3 50927905425004032  50927905425004032
# 3     1636148068921376768  Gaia DR3 50927905427219328  50927905427219328
# 4     1636148068921376768  Gaia DR3 50927974146695680  50927974146695680
# ...                   ...                         ...                ...
# 2711  1636148068921376768  Gaia DR3 51545212485723520  51545212485723520
# 2712  1636148068921376768  Gaia DR3 51545212487190144  51545212487190144
# 2713  1636148068921376768  Gaia DR3 51545212487190656  51545212487190656
# 2714  1636148068921376768  Gaia DR3 51545379988492928  51545379988492928
# 2715  1636148068921376768  Gaia DR3 51545384284415616  51545384284415616
#
#       random_index  ref_epoch         ra   ra_error        dec  dec_error  \
# 0          1085043     2016.0  58.620233   0.254919  19.853753   0.189275
# 1        942197149     2016.0  58.621395   1.453971  19.854078   1.249363
# 2        270352259     2016.0  58.607512   0.603194  19.862720   0.525238
# 3        236725479     2016.0  58.607360   0.371534  19.862937   0.276571
# 4        820867677     2016.0  58.603114   0.042696  19.876812   0.029351
# ...            ...        ...        ...        ...        ...        ...
# 2711    1382754187     2016.0  58.710826  78.683660  20.452256  63.819150
# 2712    1052554255     2016.0  58.717997   0.057421  20.452107   0.036233
# 2713    1033300959     2016.0  58.710374   0.084608  20.447327   0.051205
# 2714    1689013475     2016.0  58.681857   0.316701  20.450346   0.201248
# 2715    1184889791     2016.0  58.688903  16.659018  20.448830  11.537864
#
#       parallax  ...  azero_gspphot  azero_gspphot_lower  azero_gspphot_upper  \
# 0     2.048378  ...            NaN                  NaN                  NaN
# 1     0.884903  ...            NaN                  NaN                  NaN
# 2     0.075749  ...            NaN                  NaN                  NaN
# 3     0.507936  ...            NaN                  NaN                  NaN
# 4     2.962550  ...         1.2031               1.1757               1.2181
# ...        ...  ...            ...                  ...                  ...
# 2711       NaN  ...            NaN                  NaN                  NaN
# 2712  3.293366  ...         0.7506               0.7307               0.7691
# 2713  1.478664  ...         1.0200               0.9931               1.0572
# 2714  0.472009  ...            NaN                  NaN                  NaN
# 2715       NaN  ...            NaN                  NaN                  NaN
#
#       ag_gspphot  ag_gspphot_lower  ag_gspphot_upper  ebpminrp_gspphot  \
# 0            NaN               NaN               NaN               NaN
# 1            NaN               NaN               NaN               NaN
# 2            NaN               NaN               NaN               NaN
# 3            NaN               NaN               NaN               NaN
# 4         0.8623            0.8420            0.8734            0.4640
# ...          ...               ...               ...               ...
# 2711         NaN               NaN               NaN               NaN
# 2712      0.5103            0.4967            0.5230            0.2995
# 2713      0.7223            0.7029            0.7493            0.3945
# 2714         NaN               NaN               NaN               NaN
# 2715         NaN               NaN               NaN               NaN
#
#       ebpminrp_gspphot_lower  ebpminrp_gspphot_upper  libname_gspphot
# 0                        NaN                     NaN              NaN
# 1                        NaN                     NaN              NaN
# 2                        NaN                     NaN              NaN
# 3                        NaN                     NaN              NaN
# 4                     0.4537                  0.4698          PHOENIX
# ...                      ...                     ...              ...
# 2711                     NaN                     NaN              NaN
# 2712                  0.2917                  0.3070            MARCS
# 2713                  0.3844                  0.4084            MARCS
# 2714                     NaN                     NaN              NaN
# 2715                     NaN                     NaN              NaN
#
# [2716 rows x 152 columns]

# %%
limmag1,limmag2 = 6.0,16.0
#limmag1,limmag2 = -1000.0,1000.0

ra, dec, gmag = get_Gaia_data(yr,limmag1,limmag2, df)
len(ra)
# Out:
# 223

# %%
transform_mtx = np.array([[ hdr['CD1_1'], hdr['CD1_2'] ], \
                          [ hdr['CD2_1'], hdr['CD2_2'] ]])

x0, y0 = hdr['CRPIX1'], hdr['CRPIX2']
                          
def tangential_to_pixel(xi, eta, transform=transform_mtx, x0=x0, y0=y0):
    x, y = np.dot(np.linalg.inv(transform), [xi, eta]) + np.array([x0, y0])
    return x, y

def pixel_to_tangential(x, y, transform=transform_mtx, x0=x0, y0=y0):
    xi, eta = np.dot(transform, [x-x0, y-y0])
    return xi, eta

# %%
def eq2pix(ra, dec, transform=transform_mtx, x0=x0, y0=y0):
    return tangential_to_pixel(*np.rad2deg( 
                                equatorial_to_tangential(*np.deg2rad((ra, dec, ra0, dec0)))), transform, x0, y0)

# %%
### Фильтруем звёзды

# %%
W = WCS(hdul[0].header)
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set MJD-OBS to 60939.946526 from DATE-OBS.
# Set MJD-END to 60939.946648 from DATE-END'. [astropy.wcs.wcs]

# %%
bdr = 50
pxpos = W.wcs_world2pix(np.stack((ra, dec), axis=-1),1)  

p_indx = np.where((pxpos[:,0]>bdr) & (pxpos[:,1]>bdr) & (pxpos[:,0]<w-bdr) & (pxpos[:,1]<h-bdr))

pxpos = pxpos[p_indx]
ra,dec,gmag = ra[p_indx],dec[p_indx],gmag[p_indx]

x = [p[0] for p in pxpos]
y = [p[1] for p in pxpos]

# %%
### Отмечаем на кадре

# %%
from astropy.stats import sigma_clip

img_processed = sigma_clip(img, sigma_lower=10.0, sigma_upper=10.0) # Возводим в квадрат для увеличения контраста

fig, ax = plt.subplots(figsize=(3.0,3.0), dpi=300)
ax.xaxis.set_tick_params(labelsize=5)
ax.yaxis.set_tick_params(labelsize=5)
plt.tight_layout()

ax.imshow(img_processed, origin='lower', cmap="gray") 
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
size = 10
line_width = 0.2
ax.scatter(x, y, marker='s', facecolors='none', edgecolors='red', s=size, lw=line_width)

# %%
### Получаем координаты регрессией PSF

# %%
from scipy.optimize import curve_fit

# %%
def gaussian2D(xy,*p):
    x, y = xy
    Ibkg,Imax,A,B,C,xc,yc = p
    r = A*(x-xc)**2+C*(y-yc)**2+B*(x-xc)*(y-yc)
    return Ibkg+Imax*np.exp(-r)

def moffat(xy, *p):
    x, y = xy
    Ibkg, Imax, alpha, beta, xc, yc = p
    r2 = (x - xc)**2 + (y - yc)**2
    return Ibkg + Imax * (1 + r2 / alpha**2) ** (-beta)

def im_centroiding(I):
    h, w = I.shape

    xx, yy = np.meshgrid(np.arange(w), np.arange(h))
    xdata = (xx.ravel(), yy.ravel())
    ydata = I.ravel()

    # gaussian
    Ib = np.median(I)
    Im = np.max(I)
    A = C = 1/5
    B = 0.0
    xc0 = w // 2
    yc0 = h // 2
    #popt, pcov = curve_fit(f=gaussian2D, p0=[Ib, Im, A, B, C, xc0, yc0],
    #                       xdata=xdata, ydata=ydata, maxfev=1000)
    
    alpha = (h+w)/8.0
    beta = 2.0
    popt, pcov = curve_fit(f=moffat, p0=[Ib, Im, alpha, beta, xc0, yc0],
                           xdata=xdata, ydata=ydata, maxfev=1000)
    return popt, pcov

# %%
ap = size
xp,yp = [],[]
xi,eta = [],[]
num_success = num_failure = num_accepted = 0
for px, py in (pxpos).astype(int):
    I = img[px-ap:px+ap,py-ap:py+ap]
    print(I.shape)
    print(I.ravel().shape)
    try:
        p, covp = im_centroiding(I)
        num_success += 1
        print((px,py), "\tRegression success")
    except:
        num_failure += 1
        print((px,py), "\tRegression failure")
        continue
    
    threshold = 0.5
    if 0.0<=covp[-1,-1]<threshold*2 and 0.0<=covp[-2,-2]<threshold**2:
        num_accepted += 1
        xp.append(px-ap+xc)
        yp.append(py-ap+yc)
        # добавить свою функцию для вычисления тангенциальных координат
        tx,ty = pixel_to_tangential(xp[-1], yp[-1])
        xi.append(tx)
        eta.append(ty)
print(f"number of failures: {num_failure}\number of successes: {num_success}\nof those accepted: {num_accepted}")
# Out:
# (20, 20)
# (400,)
# (128, 1164) 	Regression success
# (20, 20)
# (400,)
# (1293, 1229) 	Regression success
# (20, 20)
# (400,)
# (770, 1308) 	Regression failure
# (20, 20)
# (400,)
# (240, 983) 	Regression success
# (20, 20)
# (400,)
# (395, 1067) 	Regression success
# (20, 20)
# (400,)
# (833, 1225) 	Regression failure
# (20, 20)
# (400,)
# (1073, 1124) 	Regression success
# (20, 20)
# (400,)
# (864, 913) 	Regression success
# (20, 20)
# (400,)
# (759, 909) 	Regression success
# (20, 20)
# (400,)
# (598, 860) 	Regression success
# (0, 20)
# (0,)
# (1537, 1111) 	Regression failure
# (0, 20)
# (0,)
# (1716, 910) 	Regression failure
# (0, 20)
# (0,)
# (1734, 611) 	Regression failure
# (20, 20)
# (400,)
# (912, 703) 	Regression success
# (20, 20)
# (400,)
# (1176, 446) 	Regression success
# (0, 20)
# (0,)
# (1494, 147) 	Regression failure
# (0, 20)
# (0,)
# (1790, 294) 	Regression failure
# (0, 20)
# (0,)
# (1804, 92) 	Regression failure
# (20, 20)
# (400,)
# (139, 790) 	Regression success
# (20, 20)
# (400,)
# (78, 639) 	Regression failure
# (20, 20)
# (400,)
# (500, 493) 	Regression success
# (20, 20)
# (400,)
# (500, 496) 	Regression success
# (20, 20)
# (400,)
# (348, 246) 	Regression success
# (20, 20)
# (400,)
# (997, 58) 	Regression success
# number of failures: 9
# umber of successes: 15
# of those accepted: 5
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py:3441: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
### Уточняем параметры МНК

# %%
Lxi = xi
Leta = eta
C = np.column_stack((xp, yp, np.ones_like(xp)))

# %%
zxi, residuals, rank, s = np.linalg.lstsq(C, Lxi, rcond=None)
zeta, residuals, rank, s = np.linalg.lstsq(C, Leta, rcond=None)
print(zxi)
print(zeta)
# Out:
# [-1.35885864e-04 -2.52965337e-06  1.42630368e-01]
# [ 2.60277920e-06 -1.36008882e-04  9.32564854e-02]

# %%
new_transform = np.row_stack((zxi[0:2], zeta[0:2]))
new_x0, new_y0 = zxi[-1], zeta[-1]

new_transform
# Out:
# array([[-1.35885864e-04, -2.52965337e-06],
#        [ 2.60277920e-06, -1.36008882e-04]])

# %%
### Отмечаем на кадре для сравнения

# %%
bdr=0
pxpos = np.array([eq2pix(r, d, new_transform, new_x0, new_y0) for r,d in zip(ra,dec)]) 

p_indx = np.where((pxpos[:,0]>bdr) & (pxpos[:,1]>bdr) & (pxpos[:,0]<w-bdr) & (pxpos[:,1]<h-bdr))

#pxpos = pxpos[p_indx]
#ra,dec,gmag = ra[p_indx],dec[p_indx],gmag[p_indx]

new_x = [p[0] for p in pxpos]
new_y = [p[1] for p in pxpos]

# %%
size = 10*sqrt(2.0)
line_width = 0.2
ax.scatter(x, y, marker='o', facecolors='none', edgecolors='green', s=size, lw=line_width)

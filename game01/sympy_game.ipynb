# %%
from sympy import *
# init_printing()

x=Symbol('x')
f = 1/(x)
integrate(f,x)
# Out:
# log(x)

# %%
H = Symbol('H')
A = Symbol('A')
B = Symbol('B')
C = Symbol('C')
D = Symbol('D')
h = Symbol('h')
I1=A/(C+D*cos(H))
I2=(B*cos(H))/(C+D*cos(H))

# %%
integrate(I1,H) - integrate(I2,H)
# Out:
# A*Piecewise((zoo*(-log(tan(H/2) - 1) + log(tan(H/2) + 1)), Eq(C, 0) & Eq(D, 0)), (1/(D*tan(H/2)), Eq(C, -D)), (tan(H/2)/D, Eq(C, D)), (log(-sqrt(-C/(C - D) - D/(C - D)) + tan(H/2))/(C*sqrt(-C/(C - D) - D/(C - D)) - D*sqrt(-C/(C - D) - D/(C - D))) - log(sqrt(-C/(C - D) - D/(C - D)) + tan(H/2))/(C*sqrt(-C/(C - D) - D/(C - D)) - D*sqrt(-C/(C - D) - D/(C - D))), True)) - B*Piecewise((zoo*H, Eq(C, 0) & Eq(D, 0)), (H/D - tan(H/2)/D, Eq(C, D)), (H/D + 1/(D*tan(H/2)), Eq(C, -D)), (sin(H)/C, Eq(D, 0)), (C*H*sqrt(-C/(C - D) - D/(C - D))/(C*D*sqrt(-C/(C - D) - D/(C - D)) - D**2*sqrt(-C/(C - D) - D/(C - D))) - C*log(-sqrt(-C/(C - D) - D/(C - D)) + tan(H/2))/(C*D*sqrt(-C/(C - D) - D/(C - D)) - D**2*sqrt(-C/(C - D) - D/(C - D))) + C*log(sqrt(-C/(C - D) - D/(C - D)) + tan(H/2))/(C*D*sqrt(-C/(C - D) - D/(C - D)) - D**2*sqrt(-C/(C - D) - D/(C - D))) - D*H*sqrt(-C/(C - D) - D/(C - D))/(C*D*sqrt(-C/(C - D) - D/(C - D)) - D**2*sqrt(-C/(C - D) - D/(C - D))), True))
